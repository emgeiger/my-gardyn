# %% [markdown]
# <a href="https://colab.research.google.com/github/emgeiger/my-gardyn/blob/Colab/Gardyn_Plant_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import BeautifulSoup(4), for webscraping.

# !pip install beautifulsoup4

# Now you can use the soup object to parse the HTML
# For example, to find all the links on the page:
# for link in soup.find_all("a"):
#     print(link.get("href"))
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.0)

# %%
from bs4 import BeautifulSoup
import requests

# %%
import sys

# %%
# Load the webpage
url = "https://help.mygardyn.com/en/articles/1776961"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# Main content section
# main_section = soup.find("div", attrs={"data-link": "all_plants_placement_guide"})
# if not main_section:
#    raise Exception("Could not find All Plants Placement Guide section.")

# %%
high_light_links = []
medium_light_links = []
low_light_links = []

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json # To pretty-print the results

def scrape_links_by_section(url):
    """
    Scrapes links from a specific URL and categorizes them based on
    preceding section headers (High, Medium, Low Light Zones).

    Args:
        url (str): The URL of the article to scrape.

    Returns:
        dict: A dictionary containing three lists of links ('High', 'Medium', 'Low'),
              or None if an error occurs. Each link is a dict {'text': str, 'url': str}.
    """
    # Standard User-Agent to mimic a browser
    request_headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    try:
        response = requests.get(url, headers=request_headers, timeout=15)
        response.raise_for_status() # Check for HTTP errors
        print(f"Successfully fetched URL: {url}")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        return None

    soup = BeautifulSoup(response.content, 'html.parser')

    # --- Find the main article content area ---
    # Inspecting the page, the content seems to be within <div class="article__content">
    article_content = soup.find('div', class_='article__content')
    if not article_content:
        print("Error: Could not find the main article content container (div.article__content).")
        # As a fallback, try finding the container seen in previous steps if structure changed slightly
        article_content = soup.find('div', class_='article-content')
        if not article_content:
           print("Error: Fallback container (div.article-content) also not found.")
           return None
        else:
            print("Info: Found article content using fallback selector 'div.article-content'.")


    # --- Initialize variables ---
    High_Light_Zone_Links = []
    Medium_Light_Zone_Links = []
    Low_Light_Zone_Links = []
    current_zone = None # Possible values: 'High', 'Medium', 'Low', None

    # --- Iterate through elements in the article content ---
    # We look for h3 tags as section markers and p tags for links.
    # find_all() gets all descendants, which works well here.
    for element in article_content.find_all(['h3', 'p']): # Look for headings and paragraphs
        if element.name == 'h3':
            # Check the heading text to determine the zone
            heading_text = element.get_text(strip=True)
            if 'High Light Zone' in heading_text:
                current_zone = 'High'
                print(f"\nEntering Zone: {current_zone}")
            elif 'Medium Light Zone' in heading_text:
                current_zone = 'Medium'
                print(f"Entering Zone: {current_zone}")
            elif 'Low Light Zone' in heading_text:
                current_zone = 'Low'
                print(f"Entering Zone: {current_zone}")
            # Add checks for other headings if they might reset the zone
            # else:
            #     # If we encounter another h3 that isn't a zone marker, maybe reset?
            #     # current_zone = None # Optional: uncomment if non-zone h3 should stop collection
            #     pass

        elif element.name == 'p' and current_zone:
            # If we are inside a known zone and find a paragraph, look for links
            links_in_p = element.find_all('a')
            if links_in_p:
                print(f"  Found paragraph in '{current_zone}' zone with links:")
                for link_tag in links_in_p:
                    href = link_tag.get('href')
                    link_text = link_tag.get_text(strip=True)

                    if href:
                        # Resolve relative URLs to absolute ones
                        absolute_url = urljoin(url, href.strip())

                        # Basic validation
                        if not absolute_url.startswith(('http://', 'https://')):
                             print(f"    Skipping invalid or non-HTTP URL format: {absolute_url}")
                             continue

                        link_data = {'text': link_text, 'url': absolute_url}
                        print(f"    - Link: '{link_text}' -> {absolute_url}")

                        # Append to the correct list based on the current zone
                        if current_zone == 'High':
                            High_Light_Zone_Links.append(link_data)
                        elif current_zone == 'Medium':
                            Medium_Light_Zone_Links.append(link_data)
                        elif current_zone == 'Low':
                            Low_Light_Zone_Links.append(link_data)

    return {
        'High': High_Light_Zone_Links,
        'Medium': Medium_Light_Zone_Links,
        'Low': Low_Light_Zone_Links
    }

# --- Configuration ---
TARGET_URL = 'https://help.mygardyn.com/en/articles/1776961'

# --- Execute the Scraper ---
categorized_links = scrape_links_by_section(TARGET_URL)

# --- Display Results ---
if categorized_links:
    print("\n--- Scraping Results ---")

    print("\nHigh Light Zone Links:")
    if categorized_links['High']:
        # Using json.dumps for readable list output
        print(json.dumps(categorized_links['High'], indent=2))
    else:
        print("No links found for this zone.")

    print("\nMedium Light Zone Links:")
    if categorized_links['Medium']:
        print(json.dumps(categorized_links['Medium'], indent=2))
    else:
        print("No links found for this zone.")

    print("\nLow Light Zone Links:")
    if categorized_links['Low']:
        print(json.dumps(categorized_links['Low'], indent=2))
    else:
        print("No links found for this zone.")

    # You can now access the lists directly if needed elsewhere in your project
    # High_Light_Zone = categorized_links['High']
    # Medium_Light_Zone = categorized_links['Medium']
    # Low_Light_Zone = categorized_links['Low']
    # print(f"\nVariable 'High_Light_Zone' contains {len(High_Light_Zone)} links.")

else:
    print("\nScraping failed to produce results.")
# Out:
# Successfully fetched URL: https://help.mygardyn.com/en/articles/1776961
# Error: Could not find the main article content container (div.article__content).
# Info: Found article content using fallback selector 'div.article-content'.
#
# Entering Zone: High
#   Found paragraph in 'High' zone with links:
#     - Link: 'Banana Pepper,' -> https://help.mygardyn.com/en/articles/1785345
#     - Link: 'Bi-Color Sunflower,' -> https://help.mygardyn.com/en/articles/1782529
#     - Link: 'Burrito Pepper,' -> https://help.mygardyn.com/en/articles/1785473
#     - Link: 'Candy Cane Pepper' -> https://help.mygardyn.com/en/articles/3525697
#     - Link: 'Cape Gooseberry' -> https://help.mygardyn.com/en/articles/1785281
#     - Link: 'Celosia Mix' -> https://help.mygardyn.com/en/articles/2566209
#     - Link: 'Cucumber' -> https://help.mygardyn.com/en/articles/1785537
#     - Link: 'Fairytale Eggplant' -> https://help.mygardyn.com/en/articles/1785601
#     - Link: 'Fuchsia Snapdragon' -> https://help.mygardyn.com/en/articles/1867009
#     - Link: 'Goliath Pepper' -> https://help.mygardyn.com/en/articles/1785857
#     - Link: 'Holy Basil' -> https://help.mygardyn.com/en/articles/1784257
#     - Link: 'Hungarian Hot Wax Pepper' -> https://help.mygardyn.com/en/articles/1785793
#     - Link: 'Jalapeño' -> https://help.mygardyn.com/en/articles/1799809
#     - Link: 'Lavender' -> https://help.mygardyn.com/en/articles/1782977
#     - Link: 'Lemon Hot Pepper' -> https://help.mygardyn.com/en/articles/1786049
#     - Link: 'Purslane' -> https://help.mygardyn.com/en/articles/1797633
#     - Link: 'Rosemary' -> https://help.mygardyn.com/en/articles/1799873
#     - Link: 'Thyme' -> https://help.mygardyn.com/en/articles/1784961
#     - Link: 'Wheatgrass' -> https://help.mygardyn.com/en/articles/1795713
#   Found paragraph in 'Low' zone with links:
#     - Link: 'Thinning' -> https://help.mygardyn.com/en/articles/1771329
#   Found paragraph in 'Low' zone with links:
#     - Link: '14-16 continuous Boost hours daily' -> https://help.mygardyn.com/en/articles/1776193
#   Found paragraph in 'Low' zone with links:
#     - Link: 'Gardyn Caps' -> https://mygardyn.com/product/gardyn-cap/
#   Found paragraph in 'Low' zone with links:
#     - Link: 'prune as needed' -> https://help.mygardyn.com/en/articles/1798849
#   Found paragraph in 'Low' zone with links:
#     Skipping invalid or non-HTTP URL format: mailto:support@mygardyn.com
#
# --- Scraping Results ---
#
# High Light Zone Links:
# [
#   {
#     "text": "Banana Pepper,",
#     "url": "https://help.mygardyn.com/en/articles/1785345"
#   },
#   {
#     "text": "Bi-Color Sunflower,",
#     "url": "https://help.mygardyn.com/en/articles/1782529"
#   },
#   {
#     "text": "Burrito Pepper,",
#     "url": "https://help.mygardyn.com/en/articles/1785473"
#   },
#   {
#     "text": "Candy Cane Pepper",
#     "url": "https://help.mygardyn.com/en/articles/3525697"
#   },
#   {
#     "text": "Cape Gooseberry",
#     "url": "https://help.mygardyn.com/en/articles/1785281"
#   },
#   {
#     "text": "Celosia Mix",
#     "url": "https://help.mygardyn.com/en/articles/2566209"
#   },
#   {
#     "text": "Cucumber",
#     "url": "https://help.mygardyn.com/en/articles/1785537"
#   },
#   {
#     "text": "Fairytale Eggplant",
#     "url": "https://help.mygardyn.com/en/articles/1785601"
#   },
#   {
#     "text": "Fuchsia Snapdragon",
#     "url": "https://help.mygardyn.com/en/articles/1867009"
#   },
#   {
#     "text": "Goliath Pepper",
#     "url": "https://help.mygardyn.com/en/articles/1785857"
#   },
#   {
#     "text": "Holy Basil",
#     "url": "https://help.mygardyn.com/en/articles/1784257"
#   },
#   {
#     "text": "Hungarian Hot Wax Pepper",
#     "url": "https://help.mygardyn.com/en/articles/1785793"
#   },
#   {
#     "text": "Jalape\u00f1o",
#     "url": "https://help.mygardyn.com/en/articles/1799809"
#   },
#   {
#     "text": "Lavender",
#     "url": "https://help.mygardyn.com/en/articles/1782977"
#   },
#   {
#     "text": "Lemon Hot Pepper",
#     "url": "https://help.mygardyn.com/en/articles/1786049"
#   },
#   {
#     "text": "Mini Broccoli",
#     "url": "https://help.mygardyn.com/en/articles/2644225"
#   },
#   {
#     "text": "Mini Cauliflower",
#     "url": "https://help.mygardyn.com/en/articles/1797249"
#   },
#   {
#     "text": "Mini Eggplant",
#     "url": "https://help.mygardyn.com/en/articles/1785985"
#   },
#   {
#     "text": "Mini Squash",
#     "url": "https://help.mygardyn.com/en/articles/2125121"
#   },
#   {
#     "text": "Mini Okra",
#     "url": "https://help.mygardyn.com/en/articles/5141633"
#   },
#   {
#     "text": "Red Mini Strawberries",
#     "url": "https://help.mygardyn.com/en/articles/1786177"
#   },
#   {
#     "text": "Poblano Pepper",
#     "url": "https://help.mygardyn.com/en/articles/2125697"
#   },
#   {
#     "text": "Portulaca Mix",
#     "url": "https://help.mygardyn.com/en/articles/2566401"
#   },
#   {
#     "text": "Purple Snapdragon",
#     "url": "https://help.mygardyn.com/en/articles/2400513"
#   },
#   {
#     "text": "Red Cherry Tomato",
#     "url": "https://help.mygardyn.com/en/articles/1786305"
#   },
#   {
#     "text": "Scarlet Snapdragon",
#     "url": "https://help.mygardyn.com/en/articles/1783361"
#   },
#   {
#     "text": "Shishito Pepper",
#     "url": "https://help.mygardyn.com/en/articles/2644353"
#   },
#   {
#     "text": "Stevia",
#     "url": "https://help.mygardyn.com/en/articles/1785153"
#   },
#   {
#     "text": "Stock Flower",
#     "url": "https://help.mygardyn.com/en/articles/1783425"
#   },
#   {
#     "text": "(Bare Root) Strawberries",
#     "url": "https://help.mygardyn.com/en/articles/1786241"
#   },
#   {
#     "text": "Sunflower",
#     "url": "https://help.mygardyn.com/en/articles/1783489"
#   },
#   {
#     "text": "Sweet Pepper",
#     "url": "https://help.mygardyn.com/en/articles/1786497"
#   },
#   {
#     "text": "Thai Eggplant",
#     "url": "https://help.mygardyn.com/en/articles/1786689"
#   },
#   {
#     "text": "Tokyo Bekana",
#     "url": "https://help.mygardyn.com/en/articles/1795969"
#   },
#   {
#     "text": "Yellow Beans",
#     "url": "https://help.mygardyn.com/en/articles/1786625"
#   },
#   {
#     "text": "Yellow Cherry Tomato",
#     "url": "https://help.mygardyn.com/en/articles/1786561"
#   },
#   {
#     "text": "Yellow Snapdragon",
#     "url": "https://help.mygardyn.com/en/articles/4256001"
#   },
#   {
#     "text": "Zinnia",
#     "url": "https://help.mygardyn.com/en/articles/4367233"
#   }
# ]
#
# Medium Light Zone Links:
# [
#   {
#     "text": "American Mustard",
#     "url": "https://help.mygardyn.com/en/articles/1780033"
#   },
#   {
#     "text": "Basil",
#     "url": "https://help.mygardyn.com/en/articles/1783873"
#   },
#   {
#     "text": "Black Viola",
#     "url": "https://help.mygardyn.com/en/articles/2644289"
#   },
#   {
#     "text": "Blue Cornflower",
#     "url": "https://help.mygardyn.com/en/articles/1782465"
#   },
#   {
#     "text": "Blush Hibiscus",
#     "url": "https://help.mygardyn.com/en/articles/1782401"
#   },
#   {
#     "text": "Borage",
#     "url": "https://help.mygardyn.com/en/articles/1782657"
#   },
#   {
#     "text": "Breen",
#     "url": "https://help.mygardyn.com/en/articles/1796161"
#   },
#   {
#     "text": "Bronze Arrow",
#     "url": "https://help.mygardyn.com/en/articles/2348737"
#   },
#   {
#     "text": "Bull's Blood Beets",
#     "url": "https://help.mygardyn.com/en/articles/1796225"
#   },
#   {
#     "text": "Buttercrunch",
#     "url": "https://help.mygardyn.com/en/articles/1796417"
#   },
#   {
#     "text": "Butterhead",
#     "url": "https://help.mygardyn.com/en/articles/1780481"
#   },
#   {
#     "text": "Canna Flower",
#     "url": "https://help.mygardyn.com/en/articles/1782593"
#   },
#   {
#     "text": "Cardinale",
#     "url": "https://help.mygardyn.com/en/articles/1796481"
#   },
#   {
#     "text": "Celery",
#     "url": "https://help.mygardyn.com/en/articles/1796545"
#   },
#   {
#     "text": "Chamomile",
#     "url": "https://help.mygardyn.com/en/articles/1782721"
#   },
#   {
#     "text": "Collard Greens",
#     "url": "https://help.mygardyn.com/en/articles/1796609"
#   },
#   {
#     "text": "Dianthus",
#     "url": "https://help.mygardyn.com/en/articles/2566529"
#   },
#   {
#     "text": "Endive Lettuce",
#     "url": "https://help.mygardyn.com/en/articles/1796673"
#   },
#   {
#     "text": "Fiesta Gitana",
#     "url": "https://help.mygardyn.com/en/articles/1782785"
#   },
#   {
#     "text": "Flashy Trout Back",
#     "url": "https://help.mygardyn.com/en/articles/1796737"
#   },
#   {
#     "text": "Green Beans",
#     "url": "https://help.mygardyn.com/en/articles/1785665"
#   },
#   {
#     "text": "Green Bok Choy",
#     "url": "https://help.mygardyn.com/en/articles/1796033"
#   },
#   {
#     "text": "Green Cabbage",
#     "url": "https://help.mygardyn.com/en/articles/4256513"
#   },
#   {
#     "text": "Green Mustard",
#     "url": "https://help.mygardyn.com/en/articles/1796801"
#   },
#   {
#     "text": "Green Salanova",
#     "url": "https://help.mygardyn.com/en/articles/2349057"
#   },
#   {
#     "text": "Green Tatsoi",
#     "url": "https://help.mygardyn.com/en/articles/1796865"
#   },
#   {
#     "text": "Hon Tsai Tai",
#     "url": "https://help.mygardyn.com/en/articles/1796929"
#   },
#   {
#     "text": "Iceberg",
#     "url": "https://help.mygardyn.com/en/articles/2348801"
#   },
#   {
#     "text": "Italian Parsley",
#     "url": "https://help.mygardyn.com/en/articles/1784321"
#   },
#   {
#     "text": "Kale",
#     "url": "https://help.mygardyn.com/en/articles/1796993"
#   },
#   {
#     "text": "Kale Lacinato",
#     "url": "https://help.mygardyn.com/en/articles/1797057"
#   },
#   {
#     "text": "Lime Basil",
#     "url": "https://help.mygardyn.com/en/articles/1783681"
#   },
#   {
#     "text": "Lollo Rossa",
#     "url": "https://help.mygardyn.com/en/articles/1797121"
#   },
#   {
#     "text": "Marietta Marigold",
#     "url": "https://help.mygardyn.com/en/articles/1782849"
#   },
#   {
#     "text": "Matilda",
#     "url": "https://help.mygardyn.com/en/articles/1780929"
#   },
#   {
#     "text": "Monte Carlo",
#     "url": "https://help.mygardyn.com/en/articles/1797313"
#   },
#   {
#     "text": "Muir Lettuce",
#     "url": "https://help.mygardyn.com/en/articles/5249729"
#   },
#   {
#     "text": "Nasturtium",
#     "url": "https://help.mygardyn.com/en/articles/1783169"
#   },
#   {
#     "text": "Night-Scented Stock",
#     "url": "https://help.mygardyn.com/en/articles/1783233"
#   },
#   {
#     "text": "Peas",
#     "url": "https://help.mygardyn.com/en/articles/1786433"
#   },
#   {
#     "text": "Perpetual Spinach",
#     "url": "https://help.mygardyn.com/en/articles/1797377"
#   },
#   {
#     "text": "Pink Celery",
#     "url": "https://help.mygardyn.com/en/articles/1797441"
#   },
#   {
#     "text": "Pink Petunia",
#     "url": "https://help.mygardyn.com/en/articles/1783105"
#   },
#   {
#     "text": "Pink Swiss Chard",
#     "url": "https://help.mygardyn.com/en/articles/2400385"
#   },
#   {
#     "text": "Purple Basil",
#     "url": "https://help.mygardyn.com/en/articles/1784769"
#   },
#   {
#     "text": "Purple Beans",
#     "url": "https://help.mygardyn.com/en/articles/1786369"
#   },
#   {
#     "text": "Purple Bok Choy",
#     "url": "https://help.mygardyn.com/en/articles/1797505"
#   },
#   {
#     "text": "Purple Campanula",
#     "url": "https://help.mygardyn.com/en/articles/1782913"
#   },
#   {
#     "text": "Purple Kohlrabi",
#     "url": "https://help.mygardyn.com/en/articles/1797569"
#   },
#   {
#     "text": "Radicchio",
#     "url": "https://help.mygardyn.com/en/articles/1781761"
#   },
#   {
#     "text": "Radio Calendula",
#     "url": "https://help.mygardyn.com/en/articles/1783297"
#   },
#   {
#     "text": "Red Amaranth",
#     "url": "https://help.mygardyn.com/en/articles/1797761"
#   },
#   {
#     "text": "Red Hibiscus",
#     "url": "https://help.mygardyn.com/en/articles/1782401"
#   },
#   {
#     "text": "Red Impatiens",
#     "url": "https://help.mygardyn.com/en/articles/3123137"
#   },
#   {
#     "text": "Red Mustard",
#     "url": "https://help.mygardyn.com/en/articles/1797889"
#   },
#   {
#     "text": "Red Oak Leaf Lettuce",
#     "url": "https://help.mygardyn.com/en/articles/1797953"
#   },
#   {
#     "text": "Red Romaine",
#     "url": "https://help.mygardyn.com/en/articles/1798017"
#   },
#   {
#     "text": "Red Sails Lettuce",
#     "url": "https://help.mygardyn.com/en/articles/1798081"
#   },
#   {
#     "text": "Red Salad Bowl",
#     "url": "https://help.mygardyn.com/en/articles/1798145"
#   },
#   {
#     "text": "Red Sorrel",
#     "url": "https://help.mygardyn.com/en/articles/1798209"
#   },
#   {
#     "text": "Red Tatsoi",
#     "url": "https://help.mygardyn.com/en/articles/1798273"
#   },
#   {
#     "text": "Red Swiss Chard",
#     "url": "https://help.mygardyn.com/en/articles/1798529"
#   },
#   {
#     "text": "Romaine",
#     "url": "https://help.mygardyn.com/en/articles/1798337"
#   },
#   {
#     "text": "Rouge d'Hiver",
#     "url": "https://help.mygardyn.com/en/articles/1798401"
#   },
#   {
#     "text": "Sage",
#     "url": "https://help.mygardyn.com/en/articles/1784641"
#   },
#   {
#     "text": "Savory",
#     "url": "https://help.mygardyn.com/en/articles/1784897"
#   },
#   {
#     "text": "Sorrel",
#     "url": "https://help.mygardyn.com/en/articles/1798465"
#   },
#   {
#     "text": "Shiso",
#     "url": "https://help.mygardyn.com/en/articles/1785025"
#   },
#   {
#     "text": "Sweet Marjoram",
#     "url": "https://help.mygardyn.com/en/articles/1785217"
#   },
#   {
#     "text": "Sweet Thai Basil",
#     "url": "https://help.mygardyn.com/en/articles/1785089"
#   },
#   {
#     "text": "Tarragon",
#     "url": "https://help.mygardyn.com/en/articles/1784577"
#   },
#   {
#     "text": "Torenia",
#     "url": "https://help.mygardyn.com/en/articles/1783553"
#   },
#   {
#     "text": "Viola",
#     "url": "https://help.mygardyn.com/en/articles/1783617"
#   },
#   {
#     "text": "Wasabi Greens",
#     "url": "https://help.mygardyn.com/en/articles/1795905"
#   },
#   {
#     "text": "Watercress",
#     "url": "https://help.mygardyn.com/en/articles/1795777"
#   },
#   {
#     "text": "White Kohlrabi",
#     "url": "https://help.mygardyn.com/en/articles/3519233"
#   },
#   {
#     "text": "White Petunia",
#     "url": "https://help.mygardyn.com/en/articles/1866945"
#   },
#   {
#     "text": "Yellow Mini Strawberry",
#     "url": "https://help.mygardyn.com/en/articles/4367169"
#   },
#   {
#     "text": "Yellow Swiss Chard",
#     "url": "https://help.mygardyn.com/en/articles/2400321"
#   }
# ]
#
# Low Light Zone Links:
# [
#   {
#     "text": "Arugula",
#     "url": "https://help.mygardyn.com/en/articles/1795649"
#   },
#   {
#     "text": "Bunching Onions",
#     "url": "https://help.mygardyn.com/en/articles/1783745"
#   },
#   {
#     "text": "Catnip",
#     "url": "https://help.mygardyn.com/en/articles/1783937"
#   },
#   {
#     "text": "Chervil",
#     "url": "https://help.mygardyn.com/en/articles/1783809"
#   },
#   {
#     "text": "Chives",
#     "url": "https://help.mygardyn.com/en/articles/1784193"
#   },
#   {
#     "text": "Cilantro",
#     "url": "https://help.mygardyn.com/en/articles/1784129"
#   },
#   {
#     "text": "Dill",
#     "url": "https://help.mygardyn.com/en/articles/1784065"
#   },
#   {
#     "text": "Garlic Chives",
#     "url": "https://help.mygardyn.com/en/articles/1784001"
#   },
#   {
#     "text": "Lemon Balm",
#     "url": "https://help.mygardyn.com/en/articles/1784385"
#   },
#   {
#     "text": "Lemongrass",
#     "url": "https://help.mygardyn.com/en/articles/1784449"
#   },
#   {
#     "text": "Mint",
#     "url": "https://help.mygardyn.com/en/articles/1784513"
#   },
#   {
#     "text": "Oregano",
#     "url": "https://help.mygardyn.com/en/articles/1784833"
#   },
#   {
#     "text": "Purslane",
#     "url": "https://help.mygardyn.com/en/articles/1797633"
#   },
#   {
#     "text": "Rosemary",
#     "url": "https://help.mygardyn.com/en/articles/1799873"
#   },
#   {
#     "text": "Thyme",
#     "url": "https://help.mygardyn.com/en/articles/1784961"
#   },
#   {
#     "text": "Wheatgrass",
#     "url": "https://help.mygardyn.com/en/articles/1795713"
#   },
#   {
#     "text": "Thinning",
#     "url": "https://help.mygardyn.com/en/articles/1771329"
#   },
#   {
#     "text": "14-16 continuous Boost hours daily",
#     "url": "https://help.mygardyn.com/en/articles/1776193"
#   },
#   {
#     "text": "Gardyn Caps",
#     "url": "https://mygardyn.com/product/gardyn-cap/"
#   },
#   {
#     "text": "prune as needed",
#     "url": "https://help.mygardyn.com/en/articles/1798849"
#   }
# ]

# %% [markdown]
# ¨
